# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                       name  age                  email  password   id_card  \
# 0   tinparnus paputpamsiri   14    tinparnus@gmail.com      1234  Xckmmi43
# 1         terakan marktong   14      terakan@gmail.com      4532  Xckmni32
# 2    Халтмаагийн Ганбаатар   14  Халтмаагийн@gmail.com      3321  Xxknmi54
# 3         prasert wongtong   40      prasert@gmail.com      3321  Xxknmi12
# 4                  wong ti   15         Xaio@gmail.com      1289  XXknmi45
# 5               timmy wong   13         Wong@gmail.com      1321   Xmlni44
# 6                  yang cu   14           cu@gmail.com      1331   Xmlno11
# 7               yakub oska   20         oska@gmail.com      3321   XXkno90
# 8            sihida makuya   29      nakimov@gmail.com      3324  XXknmi49
# 9            alexi nakimov   19      nakimov@gmail.com      3322   XXkno91
# 10             timmy osaka   18        osaka@gmail.com      3311   Xkmno30
# 11             Nadia oblas   14        Nadia@gmail.com      3120    Xkmn20
# 12            lalia slavac   16       slavac@gmail.com      3201    Xomn30
#
#     score
# 0      40
# 1      40
# 2      40
# 3      39
# 4      40
# 5      40
# 6      30
# 7      20
# 8      13
# 9      13
# 10     29
# 11     20
# 12     19

# %%
plt.rcParams.update({'font.size': 7})
plt.figure(figsize=(20,20))
plt.bar(df['name'],df['age'])
plt.grid()
plt.show()

# %%
plt.rcParams.update({'font.size': 7})
plt.figure(figsize=(20,20))
plt.bar(df['name'],df['score'])
plt.grid()
plt.show()

# %%
sns.scatterplot(x='age',y='score',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='score'>

# %%
plt.rcParams.update({'font.size': 8})
plt.figure(figsize=(25,25))
plt.pie(df['score'],labels=df['name'],autopct='%1.0f%%')
plt.legend()
plt.show()

# %%
plt.rcParams.update({'font.size': 8})
plt.figure(figsize=(25,25))
plt.pie(df['age'],labels=df['name'],autopct='%1.0f%%')
plt.legend()
plt.show()
